# %%
# %matplotlib notebook

from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
Image.open('/fileserver/icdar13/rajiv/example_input/027_1.tif')
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=1 size=2547x461 at 0x7F00D4165A70>

# %%
pil_im = Image.open('/fileserver/icdar13/rajiv/example_input/027_1.tif')
plt.figure(0)
plt.imshow(pil_im)
# Out:
# <img src="data:image/png;base64,...">

# %%
pil_im = Image.open('/fileserver/nmec-handwriting/stil-writing-corpus-processed/binary_jpg/FR/FR-079-001.bin.jpg')
plt.figure(1)
plt.imshow(pil_im)
# Out:
# <img src="data:image/png;base64,...">

# %%
pil_im = Image.open('/fileserver/nmec-handwriting/stil-writing-corpus/French/French-Images/FR-003-001.tif')
plt.figure()
plt.imshow(pil_im)
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.figure()
plt.imshow(pil_im, cmap=cm.Greys)
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.figure()
plt.imshow(pil_im, cmap=cm.Greys_r)
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.figure()
plt.imshow(pil_im, cmap=plt.cm.binary)
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.figure()
plt.imshow(pil_im, cmap=plt.cm.binary_r)
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.figure()
pil_image = Image.open('/fileserver/icdar13/experimental/027_1.tif')
plt.imshow(pil_image, cmap=cm.Greys_r)
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.figure()
pil_image = Image.open('/fileserver/icdar13/benchmarking/027_1.tif')
plt.imshow(pil_image)
# Out:
# <img src="data:image/png;base64,...">

# %%
img1 = Image.open('/fileserver/icdar13/experimental/027_1.tif')
img2 = Image.open('/fileserver/icdar13/experimental/027_2.tif')
img3 = Image.open('/fileserver/icdar13/experimental/028_1.tif')
plt.figure()
plt.imshow(img1)
plt.figure()
plt.imshow(img2)
plt.figure()
plt.imshow(img3)
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
plt.figure()
exp_default = Image.open('/fileserver/icdar13/experimental/027_1.tif')
exp_binary = Image.open('/fileserver/icdar13/jimbo/processed/binary/027_1.bin.tif')
plt.imshow(exp_default)
plt.figure()
plt.imshow(exp_binary)
exp_default
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <PIL.TiffImagePlugin.TiffImageFile image mode=1 size=2547x461 at 0x7F00ABFF8BD8>

# %%
exp_array = np.array(exp_default)
bin_array = np.array(exp_binary)
bin_array.size == exp_array.size
np.all(bin_array==exp_array)
# Out:
# True

# %%
bin_array.size
# Out:
# 1174167
