# %%
import h5py
import os
import matplotlib.pylab as plt
# %matplotlib inline

# %%
weights = h5py.File('/work/data/authors_40_forms_per_author_15_epoch_8100.hdf5.hdf5','r')

# %%
# First layer images
conv0 = weights['layer_0']['param_0']

# %%
plt.rcParams['figure.figsize'] = (12.0, 10.0)
fig, axs = plt.subplots(6,8)
for i in range(48):
    plt.subplot(6,8,i+1)
    plt.imshow(conv0[i].squeeze(), plt.get_cmap('gray'))
