# %%
import h5py
weights = h5py.File('conv2layers.hd5','r')
import os
# os.listdir('.')
weights.keys()
dir( weights['layer_0']['param_0'] )
conv0 = 1.0 - weights['layer_0']['param_0'].value

# %%
filtnum=30
filt1 = model.layers[0].get_weights()[0][filtnum].squeeze()
filt1 = 1.0 - filt1
plt.imshow(filt1, cmap=plt.get_cmap('gray'))

# %%
wn = 10
conv0wn = conv0[10].squeeze()
conv1wn = conv0[37].squeeze()
conv2wn = conv0[40].squeeze()
conv3wn = conv0[44].squeeze()

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1,4)
ax1.imshow(conv0wn, plt.get_cmap('gray'))
ax2.imshow(conv1wn, plt.get_cmap('gray'))
ax3.imshow(conv2wn, plt.get_cmap('gray'))
ax4.imshow(conv3wn, plt.get_cmap('gray'))

# plt.imshow(conv0wn, cmap=plt.get_cmap('gray'))
